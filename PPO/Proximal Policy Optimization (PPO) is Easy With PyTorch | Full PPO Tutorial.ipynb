# %%
import os
import gym
import numpy as np
import torch as T
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical

# %%
class PPOMemory:
    def __init__(self, batch_size):
        self.states = []
        self.probs = []
        self.vals = []
        self.actions = []
        self.rewards = []
        self.dones = []

        self.batch_size = batch_size

    def generate_batches(self):
        n_states = len(self.states)
        batch_start = np.arange(0, n_states, self.batch_size)
        indices = np.arange(n_states, dtype=np.int64)
        np.random.shuffle(indices)
        batches = [indices[i:i + self.batch_size] for i in batch_start]

        return np.array(self.states), \
            np.array(self.actions), \
            np.array(self.probs), \
            np.array(self.vals), \
            np.array(self.rewards), \
            np.array(self.dones), \
            batches

    def store_memory(self, state, action, probs, vals, reward, done):
        self.states.append(state)
        self.actions.append(action)
        self.probs.append(probs)
        self.vals.append(vals)
        self.rewards.append(reward)
        self.dones.append(done)

    def clear_memory(self):
        self.states = []
        self.probs = []
        self.actions = []
        self.rewards = []
        self.dones = []
        self.vals = []

# %%
class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_dims, alpha,
                 fc1_dims=256, fc2_dims=256, chkpt_dir='tmp/ppo'):
        super(ActorNetwork, self).__init__()

        self.checkpoint_file = os.path.join(chkpt_dir, 'actor_torch_ppo')
        self.actor = nn.Sequential(
            nn.Linear(*input_dims, fc1_dims),
            nn.ReLU(),
            nn.Linear(fc1_dims, fc2_dims),
            nn.ReLU(),
            nn.Linear(fc2_dims, n_actions),
            nn.Softmax(dim=-1)
        )

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        dist = self.actor(state)
        dist = Categorical(dist)

        return dist

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

# %%
class CriticNetwork(nn.Module):
    def __init__(self, input_dims, alpha, fc1_dims=256, fc2_dims=256,
                 chkpt_dir='tmp/ppo'):
        super(CriticNetwork, self).__init__()

        self.checkpoint_file = os.path.join(chkpt_dir, 'critic_torch_ppo')
        self.critic = nn.Sequential(
            nn.Linear(*input_dims, fc1_dims),
            nn.ReLU(),
            nn.Linear(fc1_dims, fc2_dims),
            nn.ReLU(),
            nn.Linear(fc2_dims, 1)
        )

        self.optimizer = optim.Adam(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        value = self.critic(state)

        return value

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

# %%
class Agent:
def __init__(self, n_actions, input_dims, gamma=0.99, alpha=0.0003, gae_lambda=0.95,
             policy_clip=0.2, batch_size=64, n_epochs=10):
    self.gamma = gamma
    self.policy_clip = policy_clip
    self.n_epochs = n_epochs
    self.gae_lambda = gae_lambda

    self.actor = ActorNetwork(n_actions, input_dims, alpha)
    self.critic = CriticNetwork(input_dims, alpha)
    self.memory = PPOMemory(batch_size)

def remember(self, state, action, probs, vals, reward, done):
    self.memory.store_memory(state, action, probs, vals, reward, done)

def save_models(self):
    print('... saving models ...')
    self.actor.save_checkpoint()
    self.critic.save_checkpoint()

def load_models(self):
    print('... loading models ...')
    self.actor.load_checkpoint()
    self.critic.load_checkpoint()

def choose_action(self, observation):
    state = T.tensor([observation], dtype=T.float).to(self.actor.device)

    dist = self.actor(state)
    value = self.critic(state)
    action = dist.sample()

    probs = T.squeeze(dist.log_prob(action)).item()
    action = T.squeeze(action).item()
    value = T.squeeze(value).item()

    return action, probs, value

def learn(self):
    for _ in range(self.n_epochs):
        state_arr, action_arr, old_prob_arr, vals_arr, \
            reward_arr, dones_arr, batches = \
            self.memory.generate_batches()

        values = vals_arr
        advantage = np.zeros(len(reward_arr), dtype=np.float32)

        for t in range(len(reward_arr) - 1):
            discount = 1
            a_t = 0
            for k in range(t, len(reward_arr) - 1):
                a_t += discount * (reward_arr[k] + self.gamma * values[k + 1] * \
                                   (1 - int(dones_arr[k])) - values[k])
                discount *= self.gamma * self.gae_lambda
            advantage[t] = a_t
        advantage = T.tensor(advantage).to(self.actor.device)

        values = T.tensor(values).to(self.actor.device)
        for batch in batches:
            states = T.tensor(state_arr[batch], dtype=T.float).to(self.actor.device)
            old_probs = T.tensor(old_prob_arr[batch]).to(self.actor.device)
            actions = T.tensor(action_arr[batch]).to(self.actor.device)

            dist = self.actor(states)
            critic_value = self.critic(states)

            critic_value = T.squeeze(critic_value)

            new_probs = dist.log_prob(actions)
            prob_ratio = new_probs.exp() / old_probs.exp()
            #prob_ratio = (new_probs - old_probs).exp()
            weighted_probs = advantage[batch] * prob_ratio
            weighted_clipped_probs = T.clamp(prob_ratio, 1 - self.policy_clip,
                                             1 + self.policy_clip) * advantage[batch]
            actor_loss = -T.min(weighted_probs, weighted_clipped_probs).mean()

            returns = advantage[batch] + values[batch]
            critic_loss = (returns - critic_value) ** 2
            critic_loss = critic_loss.mean()

            total_loss = actor_loss + 0.5 * critic_loss
            self.actor.optimizer.zero_grad()
            self.critic.optimizer.zero_grad()
            total_loss.backward()
            self.actor.optimizer.step()
            self.critic.optimizer.step()

    self.memory.clear_memory()

# %%
env = gym.make('CartPole-v1')
N = 10
batch_size = 5
n_epochs = 4
alpha = 0.003
agent = Agent(n_actions=env.action_space.n, batch_size=batch_size,
              alpha=alpha, n_epochs=n_epochs,
              input_dims=env.observation_space.shape)
n_games = 300

figure_file = 'plots/cartpole.png'

best_score = env.reward_range[0]
score_history = []

learn_iters = 0
avg_score = 0
n_steps = 0

for i in range(n_games):
    observation = env.reset()[0]
    done = False
    score = 0
    while not done:
        action, prob, val = agent.choose_action(observation)
        observation_, reward, truncated,terminated, info = env.step(action)
        n_steps += 1
        score += reward
        agent.remember(observation, action, prob, val, reward, done)
        if n_steps % N == 0:
            agent.learn()
            learn_iters += 1
        observation = observation_
        done = truncated or terminated
    score_history.append(score)
    avg_score = np.mean(score_history[-100:])

    if avg_score > best_score:
        best_score = avg_score
        # agent.save_models()

    print('episode', i, 'score %.1f' % score, 'avg score %.1f' % avg_score,
          'time_steps', n_steps, 'learning_steps', learn_iters)
# Out:
# episode 0 score 17.0 avg score 17.0 time_steps 17 learning_steps 1
# episode 1 score 44.0 avg score 30.5 time_steps 61 learning_steps 6
# episode 2 score 16.0 avg score 25.7 time_steps 77 learning_steps 7
# episode 3 score 34.0 avg score 27.8 time_steps 111 learning_steps 11
# episode 4 score 9.0 avg score 24.0 time_steps 120 learning_steps 12
# episode 5 score 9.0 avg score 21.5 time_steps 129 learning_steps 12
# episode 6 score 9.0 avg score 19.7 time_steps 138 learning_steps 13
# episode 7 score 10.0 avg score 18.5 time_steps 148 learning_steps 14
# episode 8 score 10.0 avg score 17.6 time_steps 158 learning_steps 15
# episode 9 score 9.0 avg score 16.7 time_steps 167 learning_steps 16
# episode 10 score 11.0 avg score 16.2 time_steps 178 learning_steps 17
# episode 11 score 10.0 avg score 15.7 time_steps 188 learning_steps 18
# episode 12 score 10.0 avg score 15.2 time_steps 198 learning_steps 19
# episode 13 score 10.0 avg score 14.9 time_steps 208 learning_steps 20
# episode 14 score 10.0 avg score 14.5 time_steps 218 learning_steps 21
# episode 15 score 10.0 avg score 14.2 time_steps 228 learning_steps 22
# episode 16 score 9.0 avg score 13.9 time_steps 237 learning_steps 23
# episode 17 score 9.0 avg score 13.7 time_steps 246 learning_steps 24
# episode 18 score 10.0 avg score 13.5 time_steps 256 learning_steps 25
# episode 19 score 10.0 avg score 13.3 time_steps 266 learning_steps 26
# episode 20 score 10.0 avg score 13.1 time_steps 276 learning_steps 27
# episode 21 score 10.0 avg score 13.0 time_steps 286 learning_steps 28
# episode 22 score 9.0 avg score 12.8 time_steps 295 learning_steps 29
# episode 23 score 10.0 avg score 12.7 time_steps 305 learning_steps 30
# episode 24 score 9.0 avg score 12.6 time_steps 314 learning_steps 31
# episode 25 score 11.0 avg score 12.5 time_steps 325 learning_steps 32
# episode 26 score 9.0 avg score 12.4 time_steps 334 learning_steps 33
# episode 27 score 10.0 avg score 12.3 time_steps 344 learning_steps 34
# episode 28 score 10.0 avg score 12.2 time_steps 354 learning_steps 35
# episode 29 score 9.0 avg score 12.1 time_steps 363 learning_steps 36
# episode 30 score 9.0 avg score 12.0 time_steps 372 learning_steps 37
# episode 31 score 10.0 avg score 11.9 time_steps 382 learning_steps 38
# episode 32 score 10.0 avg score 11.9 time_steps 392 learning_steps 39
# episode 33 score 8.0 avg score 11.8 time_steps 400 learning_steps 40
# episode 34 score 11.0 avg score 11.7 time_steps 411 learning_steps 41
# episode 35 score 10.0 avg score 11.7 time_steps 421 learning_steps 42
# episode 36 score 10.0 avg score 11.6 time_steps 431 learning_steps 43
# episode 37 score 9.0 avg score 11.6 time_steps 440 learning_steps 44
# episode 38 score 8.0 avg score 11.5 time_steps 448 learning_steps 44
# episode 39 score 10.0 avg score 11.4 time_steps 458 learning_steps 45
# episode 40 score 10.0 avg score 11.4 time_steps 468 learning_steps 46
# episode 41 score 10.0 avg score 11.4 time_steps 478 learning_steps 47
# episode 42 score 10.0 avg score 11.3 time_steps 488 learning_steps 48
# episode 43 score 10.0 avg score 11.3 time_steps 498 learning_steps 49
# episode 44 score 9.0 avg score 11.3 time_steps 507 learning_steps 50
# episode 45 score 10.0 avg score 11.2 time_steps 517 learning_steps 51
# episode 46 score 9.0 avg score 11.2 time_steps 526 learning_steps 52
# episode 47 score 10.0 avg score 11.2 time_steps 536 learning_steps 53
# episode 48 score 9.0 avg score 11.1 time_steps 545 learning_steps 54
# episode 49 score 10.0 avg score 11.1 time_steps 555 learning_steps 55
# episode 50 score 9.0 avg score 11.1 time_steps 564 learning_steps 56
# episode 51 score 10.0 avg score 11.0 time_steps 574 learning_steps 57
# episode 52 score 10.0 avg score 11.0 time_steps 584 learning_steps 58
# episode 53 score 10.0 avg score 11.0 time_steps 594 learning_steps 59
# episode 54 score 10.0 avg score 11.0 time_steps 604 learning_steps 60
# episode 55 score 10.0 avg score 11.0 time_steps 614 learning_steps 61
# episode 56 score 10.0 avg score 10.9 time_steps 624 learning_steps 62
# episode 57 score 10.0 avg score 10.9 time_steps 634 learning_steps 63
# episode 58 score 9.0 avg score 10.9 time_steps 643 learning_steps 64
# episode 59 score 9.0 avg score 10.9 time_steps 652 learning_steps 65
# episode 60 score 9.0 avg score 10.8 time_steps 661 learning_steps 66
# episode 61 score 11.0 avg score 10.8 time_steps 672 learning_steps 67
# episode 62 score 10.0 avg score 10.8 time_steps 682 learning_steps 68
# episode 63 score 11.0 avg score 10.8 time_steps 693 learning_steps 69
# episode 64 score 9.0 avg score 10.8 time_steps 702 learning_steps 70
# episode 65 score 9.0 avg score 10.8 time_steps 711 learning_steps 71
# episode 66 score 10.0 avg score 10.8 time_steps 721 learning_steps 72
# episode 67 score 9.0 avg score 10.7 time_steps 730 learning_steps 73
# episode 68 score 11.0 avg score 10.7 time_steps 741 learning_steps 74
# episode 69 score 9.0 avg score 10.7 time_steps 750 learning_steps 75
# episode 70 score 10.0 avg score 10.7 time_steps 760 learning_steps 76
# episode 71 score 9.0 avg score 10.7 time_steps 769 learning_steps 76
# episode 72 score 10.0 avg score 10.7 time_steps 779 learning_steps 77
# episode 73 score 10.0 avg score 10.7 time_steps 789 learning_steps 78
# episode 74 score 10.0 avg score 10.7 time_steps 799 learning_steps 79
# episode 75 score 8.0 avg score 10.6 time_steps 807 learning_steps 80
# episode 76 score 9.0 avg score 10.6 time_steps 816 learning_steps 81
# episode 77 score 9.0 avg score 10.6 time_steps 825 learning_steps 82
# episode 78 score 9.0 avg score 10.6 time_steps 834 learning_steps 83
# episode 79 score 9.0 avg score 10.5 time_steps 843 learning_steps 84
# episode 80 score 9.0 avg score 10.5 time_steps 852 learning_steps 85
# episode 81 score 10.0 avg score 10.5 time_steps 862 learning_steps 86
# episode 82 score 10.0 avg score 10.5 time_steps 872 learning_steps 87
# episode 83 score 10.0 avg score 10.5 time_steps 882 learning_steps 88
# episode 84 score 10.0 avg score 10.5 time_steps 892 learning_steps 89
# episode 85 score 9.0 avg score 10.5 time_steps 901 learning_steps 90
# episode 86 score 9.0 avg score 10.5 time_steps 910 learning_steps 91
# episode 87 score 10.0 avg score 10.5 time_steps 920 learning_steps 92
# episode 88 score 9.0 avg score 10.4 time_steps 929 learning_steps 92
# episode 89 score 9.0 avg score 10.4 time_steps 938 learning_steps 93
# episode 90 score 9.0 avg score 10.4 time_steps 947 learning_steps 94
# episode 91 score 10.0 avg score 10.4 time_steps 957 learning_steps 95
# episode 92 score 10.0 avg score 10.4 time_steps 967 learning_steps 96
# episode 93 score 10.0 avg score 10.4 time_steps 977 learning_steps 97
# episode 94 score 9.0 avg score 10.4 time_steps 986 learning_steps 98
# episode 95 score 9.0 avg score 10.4 time_steps 995 learning_steps 99
# episode 96 score 10.0 avg score 10.4 time_steps 1005 learning_steps 100
# episode 97 score 9.0 avg score 10.3 time_steps 1014 learning_steps 101
# episode 98 score 9.0 avg score 10.3 time_steps 1023 learning_steps 102
# episode 99 score 9.0 avg score 10.3 time_steps 1032 learning_steps 103
# episode 100 score 9.0 avg score 10.2 time_steps 1041 learning_steps 104
# episode 101 score 9.0 avg score 9.9 time_steps 1050 learning_steps 105
# episode 102 score 9.0 avg score 9.8 time_steps 1059 learning_steps 105
# episode 103 score 10.0 avg score 9.6 time_steps 1069 learning_steps 106
# episode 104 score 9.0 avg score 9.6 time_steps 1078 learning_steps 107
# episode 105 score 10.0 avg score 9.6 time_steps 1088 learning_steps 108
# episode 106 score 9.0 avg score 9.6 time_steps 1097 learning_steps 109
# episode 107 score 9.0 avg score 9.6 time_steps 1106 learning_steps 110
# episode 108 score 11.0 avg score 9.6 time_steps 1117 learning_steps 111
# episode 109 score 10.0 avg score 9.6 time_steps 1127 learning_steps 112
# episode 110 score 10.0 avg score 9.6 time_steps 1137 learning_steps 113
# episode 111 score 10.0 avg score 9.6 time_steps 1147 learning_steps 114
# episode 112 score 9.0 avg score 9.6 time_steps 1156 learning_steps 115
# episode 113 score 10.0 avg score 9.6 time_steps 1166 learning_steps 116
# episode 114 score 8.0 avg score 9.6 time_steps 1174 learning_steps 117
# episode 115 score 9.0 avg score 9.6 time_steps 1183 learning_steps 118
# episode 116 score 10.0 avg score 9.6 time_steps 1193 learning_steps 119
# episode 117 score 11.0 avg score 9.6 time_steps 1204 learning_steps 120
# episode 118 score 8.0 avg score 9.6 time_steps 1212 learning_steps 121
# episode 119 score 10.0 avg score 9.6 time_steps 1222 learning_steps 122
# episode 120 score 9.0 avg score 9.6 time_steps 1231 learning_steps 123
# episode 121 score 9.0 avg score 9.5 time_steps 1240 learning_steps 124
# episode 122 score 10.0 avg score 9.6 time_steps 1250 learning_steps 125
# episode 123 score 10.0 avg score 9.6 time_steps 1260 learning_steps 126
# episode 124 score 9.0 avg score 9.6 time_steps 1269 learning_steps 126
# episode 125 score 9.0 avg score 9.5 time_steps 1278 learning_steps 127
# episode 126 score 9.0 avg score 9.5 time_steps 1287 learning_steps 128
# episode 127 score 10.0 avg score 9.5 time_steps 1297 learning_steps 129
# episode 128 score 10.0 avg score 9.5 time_steps 1307 learning_steps 130
# episode 129 score 10.0 avg score 9.5 time_steps 1317 learning_steps 131
# episode 130 score 10.0 avg score 9.6 time_steps 1327 learning_steps 132
# episode 131 score 10.0 avg score 9.6 time_steps 1337 learning_steps 133
# episode 132 score 10.0 avg score 9.6 time_steps 1347 learning_steps 134
# episode 133 score 10.0 avg score 9.6 time_steps 1357 learning_steps 135
# episode 134 score 9.0 avg score 9.6 time_steps 1366 learning_steps 136
# episode 135 score 10.0 avg score 9.6 time_steps 1376 learning_steps 137
# episode 136 score 11.0 avg score 9.6 time_steps 1387 learning_steps 138
# episode 137 score 10.0 avg score 9.6 time_steps 1397 learning_steps 139
# episode 138 score 10.0 avg score 9.6 time_steps 1407 learning_steps 140
# episode 139 score 11.0 avg score 9.6 time_steps 1418 learning_steps 141
# episode 140 score 9.0 avg score 9.6 time_steps 1427 learning_steps 142
# episode 141 score 9.0 avg score 9.6 time_steps 1436 learning_steps 143
# episode 142 score 10.0 avg score 9.6 time_steps 1446 learning_steps 144
# episode 143 score 8.0 avg score 9.6 time_steps 1454 learning_steps 145
# episode 144 score 9.0 avg score 9.6 time_steps 1463 learning_steps 146
# episode 145 score 9.0 avg score 9.6 time_steps 1472 learning_steps 147
# episode 146 score 11.0 avg score 9.6 time_steps 1483 learning_steps 148
# episode 147 score 8.0 avg score 9.6 time_steps 1491 learning_steps 149
# episode 148 score 10.0 avg score 9.6 time_steps 1501 learning_steps 150
# episode 149 score 9.0 avg score 9.6 time_steps 1510 learning_steps 151
# episode 150 score 10.0 avg score 9.6 time_steps 1520 learning_steps 152
# episode 151 score 9.0 avg score 9.6 time_steps 1529 learning_steps 152
# episode 152 score 10.0 avg score 9.6 time_steps 1539 learning_steps 153
# episode 153 score 9.0 avg score 9.5 time_steps 1548 learning_steps 154
# episode 154 score 9.0 avg score 9.5 time_steps 1557 learning_steps 155
# episode 155 score 11.0 avg score 9.5 time_steps 1568 learning_steps 156
# episode 156 score 8.0 avg score 9.5 time_steps 1576 learning_steps 157
# episode 157 score 9.0 avg score 9.5 time_steps 1585 learning_steps 158
# episode 158 score 9.0 avg score 9.5 time_steps 1594 learning_steps 159
# episode 159 score 10.0 avg score 9.5 time_steps 1604 learning_steps 160
# episode 160 score 10.0 avg score 9.5 time_steps 1614 learning_steps 161
# episode 161 score 10.0 avg score 9.5 time_steps 1624 learning_steps 162
# episode 162 score 9.0 avg score 9.5 time_steps 1633 learning_steps 163
# episode 163 score 9.0 avg score 9.5 time_steps 1642 learning_steps 164
# episode 164 score 8.0 avg score 9.5 time_steps 1650 learning_steps 165
# episode 165 score 8.0 avg score 9.5 time_steps 1658 learning_steps 165
# episode 166 score 10.0 avg score 9.5 time_steps 1668 learning_steps 166
# episode 167 score 9.0 avg score 9.5 time_steps 1677 learning_steps 167
# episode 168 score 8.0 avg score 9.4 time_steps 1685 learning_steps 168
# episode 169 score 9.0 avg score 9.4 time_steps 1694 learning_steps 169
# episode 170 score 9.0 avg score 9.4 time_steps 1703 learning_steps 170
# episode 171 score 8.0 avg score 9.4 time_steps 1711 learning_steps 171
# episode 172 score 9.0 avg score 9.4 time_steps 1720 learning_steps 172
# episode 173 score 9.0 avg score 9.4 time_steps 1729 learning_steps 172
# episode 174 score 10.0 avg score 9.4 time_steps 1739 learning_steps 173
# episode 175 score 11.0 avg score 9.4 time_steps 1750 learning_steps 175
# episode 176 score 9.0 avg score 9.4 time_steps 1759 learning_steps 175
# episode 177 score 9.0 avg score 9.4 time_steps 1768 learning_steps 176
# episode 178 score 9.0 avg score 9.4 time_steps 1777 learning_steps 177
# episode 179 score 8.0 avg score 9.4 time_steps 1785 learning_steps 178
# episode 180 score 10.0 avg score 9.4 time_steps 1795 learning_steps 179
# episode 181 score 10.0 avg score 9.4 time_steps 1805 learning_steps 180
# episode 182 score 9.0 avg score 9.4 time_steps 1814 learning_steps 181
# episode 183 score 9.0 avg score 9.4 time_steps 1823 learning_steps 182
# episode 184 score 10.0 avg score 9.4 time_steps 1833 learning_steps 183
# episode 185 score 8.0 avg score 9.4 time_steps 1841 learning_steps 184
# episode 186 score 9.0 avg score 9.4 time_steps 1850 learning_steps 185
# episode 187 score 9.0 avg score 9.4 time_steps 1859 learning_steps 185
# episode 188 score 9.0 avg score 9.4 time_steps 1868 learning_steps 186
# episode 189 score 9.0 avg score 9.4 time_steps 1877 learning_steps 187
# episode 190 score 8.0 avg score 9.4 time_steps 1885 learning_steps 188
# episode 191 score 8.0 avg score 9.4 time_steps 1893 learning_steps 189
# episode 192 score 10.0 avg score 9.4 time_steps 1903 learning_steps 190
# episode 193 score 8.0 avg score 9.3 time_steps 1911 learning_steps 191
# episode 194 score 9.0 avg score 9.3 time_steps 1920 learning_steps 192
# episode 195 score 10.0 avg score 9.3 time_steps 1930 learning_steps 193
# episode 196 score 9.0 avg score 9.3 time_steps 1939 learning_steps 193
# episode 197 score 10.0 avg score 9.3 time_steps 1949 learning_steps 194
# episode 198 score 9.0 avg score 9.3 time_steps 1958 learning_steps 195
# episode 199 score 9.0 avg score 9.3 time_steps 1967 learning_steps 196
# episode 200 score 10.0 avg score 9.4 time_steps 1977 learning_steps 197
# episode 201 score 9.0 avg score 9.4 time_steps 1986 learning_steps 198
# episode 202 score 9.0 avg score 9.4 time_steps 1995 learning_steps 199
# episode 203 score 10.0 avg score 9.4 time_steps 2005 learning_steps 200
# episode 204 score 10.0 avg score 9.4 time_steps 2015 learning_steps 201
# episode 205 score 8.0 avg score 9.3 time_steps 2023 learning_steps 202
# episode 206 score 11.0 avg score 9.4 time_steps 2034 learning_steps 203
# episode 207 score 9.0 avg score 9.4 time_steps 2043 learning_steps 204
# episode 208 score 9.0 avg score 9.3 time_steps 2052 learning_steps 205
# episode 209 score 9.0 avg score 9.3 time_steps 2061 learning_steps 206
# episode 210 score 9.0 avg score 9.3 time_steps 2070 learning_steps 207
# episode 211 score 9.0 avg score 9.3 time_steps 2079 learning_steps 207
# episode 212 score 10.0 avg score 9.3 time_steps 2089 learning_steps 208
# episode 213 score 9.0 avg score 9.3 time_steps 2098 learning_steps 209
# episode 214 score 10.0 avg score 9.3 time_steps 2108 learning_steps 210
# episode 215 score 9.0 avg score 9.3 time_steps 2117 learning_steps 211
# episode 216 score 10.0 avg score 9.3 time_steps 2127 learning_steps 212
# episode 217 score 9.0 avg score 9.3 time_steps 2136 learning_steps 213
# episode 218 score 11.0 avg score 9.3 time_steps 2147 learning_steps 214
# episode 219 score 9.0 avg score 9.3 time_steps 2156 learning_steps 215
# episode 220 score 10.0 avg score 9.3 time_steps 2166 learning_steps 216
# episode 221 score 10.0 avg score 9.4 time_steps 2176 learning_steps 217
# episode 222 score 9.0 avg score 9.3 time_steps 2185 learning_steps 218
# episode 223 score 10.0 avg score 9.3 time_steps 2195 learning_steps 219
# episode 224 score 10.0 avg score 9.4 time_steps 2205 learning_steps 220
# episode 225 score 9.0 avg score 9.4 time_steps 2214 learning_steps 221
# episode 226 score 10.0 avg score 9.4 time_steps 2224 learning_steps 222
# episode 227 score 9.0 avg score 9.4 time_steps 2233 learning_steps 223
# episode 228 score 10.0 avg score 9.4 time_steps 2243 learning_steps 224
# episode 229 score 8.0 avg score 9.3 time_steps 2251 learning_steps 225
# episode 230 score 10.0 avg score 9.3 time_steps 2261 learning_steps 226
# episode 231 score 8.0 avg score 9.3 time_steps 2269 learning_steps 226
# episode 232 score 10.0 avg score 9.3 time_steps 2279 learning_steps 227
# episode 233 score 9.0 avg score 9.3 time_steps 2288 learning_steps 228
# episode 234 score 10.0 avg score 9.3 time_steps 2298 learning_steps 229
# episode 235 score 10.0 avg score 9.3 time_steps 2308 learning_steps 230
# episode 236 score 9.0 avg score 9.3 time_steps 2317 learning_steps 231
# episode 237 score 8.0 avg score 9.3 time_steps 2325 learning_steps 232
# episode 238 score 8.0 avg score 9.3 time_steps 2333 learning_steps 233
# episode 239 score 9.0 avg score 9.2 time_steps 2342 learning_steps 234
# episode 240 score 8.0 avg score 9.2 time_steps 2350 learning_steps 235
# episode 241 score 8.0 avg score 9.2 time_steps 2358 learning_steps 235
# episode 242 score 9.0 avg score 9.2 time_steps 2367 learning_steps 236
# episode 243 score 9.0 avg score 9.2 time_steps 2376 learning_steps 237
# episode 244 score 10.0 avg score 9.2 time_steps 2386 learning_steps 238
# episode 245 score 9.0 avg score 9.2 time_steps 2395 learning_steps 239
# episode 246 score 9.0 avg score 9.2 time_steps 2404 learning_steps 240
# episode 247 score 10.0 avg score 9.2 time_steps 2414 learning_steps 241
# episode 248 score 10.0 avg score 9.2 time_steps 2424 learning_steps 242
# episode 249 score 9.0 avg score 9.2 time_steps 2433 learning_steps 243
# episode 250 score 10.0 avg score 9.2 time_steps 2443 learning_steps 244
# episode 251 score 9.0 avg score 9.2 time_steps 2452 learning_steps 245
# episode 252 score 9.0 avg score 9.2 time_steps 2461 learning_steps 246
# episode 253 score 10.0 avg score 9.2 time_steps 2471 learning_steps 247
# episode 254 score 8.0 avg score 9.2 time_steps 2479 learning_steps 247
# episode 255 score 10.0 avg score 9.2 time_steps 2489 learning_steps 248
# episode 256 score 9.0 avg score 9.2 time_steps 2498 learning_steps 249
# episode 257 score 10.0 avg score 9.2 time_steps 2508 learning_steps 250
# episode 258 score 9.0 avg score 9.2 time_steps 2517 learning_steps 251
# episode 259 score 10.0 avg score 9.2 time_steps 2527 learning_steps 252
# episode 260 score 10.0 avg score 9.2 time_steps 2537 learning_steps 253
# episode 261 score 10.0 avg score 9.2 time_steps 2547 learning_steps 254
# episode 262 score 9.0 avg score 9.2 time_steps 2556 learning_steps 255
# episode 263 score 9.0 avg score 9.2 time_steps 2565 learning_steps 256
# episode 264 score 9.0 avg score 9.2 time_steps 2574 learning_steps 257
# episode 265 score 10.0 avg score 9.3 time_steps 2584 learning_steps 258
# episode 266 score 10.0 avg score 9.3 time_steps 2594 learning_steps 259
# episode 267 score 10.0 avg score 9.3 time_steps 2604 learning_steps 260
# episode 268 score 10.0 avg score 9.3 time_steps 2614 learning_steps 261
# episode 269 score 10.0 avg score 9.3 time_steps 2624 learning_steps 262
# episode 270 score 8.0 avg score 9.3 time_steps 2632 learning_steps 263
# episode 271 score 8.0 avg score 9.3 time_steps 2640 learning_steps 264
# episode 272 score 9.0 avg score 9.3 time_steps 2649 learning_steps 264
# episode 273 score 11.0 avg score 9.3 time_steps 2660 learning_steps 266
# episode 274 score 10.0 avg score 9.3 time_steps 2670 learning_steps 267
# episode 275 score 10.0 avg score 9.3 time_steps 2680 learning_steps 268
# episode 276 score 10.0 avg score 9.3 time_steps 2690 learning_steps 269
# episode 277 score 9.0 avg score 9.3 time_steps 2699 learning_steps 269
# episode 278 score 9.0 avg score 9.3 time_steps 2708 learning_steps 270
# episode 279 score 10.0 avg score 9.3 time_steps 2718 learning_steps 271
# episode 280 score 9.0 avg score 9.3 time_steps 2727 learning_steps 272
# episode 281 score 8.0 avg score 9.3 time_steps 2735 learning_steps 273
# episode 282 score 9.0 avg score 9.3 time_steps 2744 learning_steps 274
# episode 283 score 10.0 avg score 9.3 time_steps 2754 learning_steps 275
# episode 284 score 10.0 avg score 9.3 time_steps 2764 learning_steps 276
# episode 285 score 10.0 avg score 9.3 time_steps 2774 learning_steps 277
# episode 286 score 11.0 avg score 9.3 time_steps 2785 learning_steps 278
# episode 287 score 10.0 avg score 9.4 time_steps 2795 learning_steps 279
# episode 288 score 9.0 avg score 9.4 time_steps 2804 learning_steps 280
# episode 289 score 9.0 avg score 9.4 time_steps 2813 learning_steps 281
# episode 290 score 9.0 avg score 9.4 time_steps 2822 learning_steps 282
# episode 291 score 8.0 avg score 9.4 time_steps 2830 learning_steps 283
# episode 292 score 10.0 avg score 9.4 time_steps 2840 learning_steps 284
# episode 293 score 10.0 avg score 9.4 time_steps 2850 learning_steps 285
# episode 294 score 9.0 avg score 9.4 time_steps 2859 learning_steps 285
# episode 295 score 10.0 avg score 9.4 time_steps 2869 learning_steps 286
# episode 296 score 8.0 avg score 9.4 time_steps 2877 learning_steps 287
# episode 297 score 9.0 avg score 9.4 time_steps 2886 learning_steps 288
# episode 298 score 10.0 avg score 9.4 time_steps 2896 learning_steps 289
# episode 299 score 8.0 avg score 9.4 time_steps 2904 learning_steps 290
